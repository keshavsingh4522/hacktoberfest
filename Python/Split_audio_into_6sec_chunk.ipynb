# %%
from pydub import AudioSegment
import math

class SplitWavAudioMubin():
    def __init__(self, folder, filename):
        self.folder = folder
        self.filename = filename
        self.filepath = folder + '\\' + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(self.folder + '/DATASET3/' + split_filename, format="wav")
        
    def multiple_split(self, sec_per_split):
        total_sec = math.ceil(self.get_duration() )
        for i in range(0, total_sec, sec_per_split):
            split_fn = str(i) + '_' + self.filename
            self.single_split(i, i+sec_per_split, split_fn)
            print(str(i) + ' Done')
            if i == total_sec - sec_per_split:
                print('All splited successfully')

# %%
folder = 'C:/Users/bhask/Desktop/Audio/modi/dataset/dataset'
file = 'dataset3.wav'
split_wav = SplitWavAudioMubin(folder, file)
split_wav.multiple_split(sec_per_split=6)
# Out:
# 0 Done
# 6 Done
# 12 Done
# 18 Done
# 24 Done
# 30 Done
# 36 Done
# 42 Done
# 48 Done
# 54 Done
# 60 Done
# 66 Done
# 72 Done
# 78 Done
# 84 Done
# 90 Done
# 96 Done
# 102 Done
# 108 Done
# 114 Done
# 120 Done
# 126 Done
# 132 Done
# 138 Done
# 144 Done
# 150 Done
# 156 Done
# 162 Done
# 168 Done
# 174 Done
# 180 Done
# 186 Done
# 192 Done
# 198 Done
# 204 Done
# 210 Done
# 216 Done
# 222 Done
# 228 Done
# 234 Done
# 240 Done
# 246 Done
# 252 Done
# 258 Done
# 264 Done
# 270 Done
# 276 Done
# 282 Done
# 288 Done
# 294 Done
# 300 Done
# 306 Done
# 312 Done
# 318 Done
# 324 Done
# 330 Done
# 336 Done
# 342 Done
# 348 Done
# 354 Done
# 360 Done
# 366 Done
# 372 Done
# 378 Done
# 384 Done
# 390 Done
# 396 Done
# 402 Done
# 408 Done
# 414 Done
# 420 Done
# 426 Done
# 432 Done
# 438 Done
# 444 Done
# 450 Done
# 456 Done
# 462 Done
# 468 Done
# 474 Done
# 480 Done
# 486 Done
# 492 Done
# 498 Done
# 504 Done
# 510 Done
# 516 Done
# 522 Done
# 528 Done
# 534 Done
# 540 Done
# 546 Done
# ...
