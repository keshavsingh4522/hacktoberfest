# %%
# import os
# from scipy.io.wavfile import read as read_wav

# os.chdir('C:/Users/bhask/Downloads/splited') # change to the file directory
# sampling_rate, data=read_wav("merged_1000.wav") # enter your filename
# print (sampling_rate)

# %%
# from os import walk
# mypath='C:/Users/bhask/Downloads/splited'
# filenames = next(walk(mypath), (None, None, []))[2]  # [] if no file

# %%
# import required module
import glob
from scipy.io.wavfile import read as read_wav

# assign directory
directory = 
 
# iterate over files in
# that directory
for filename in glob.iglob(f'{directory}/*'):
    sampling_rate, data=read_wav(filename) # enter your filename
    print(filename,str(sampling_rate) + " hertz")
#     print (sampling_rate)
# Out:
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\0_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\10002_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\10008_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1002_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1008_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1014_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1020_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1026_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\102_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1032_dataset3.wav 44100 hertz
# C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3\1038_dataset3.wav 44100 hertz
# ...

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %%
librosa.util.example_audio_file()
librosa.get_samplerate(path)
import soundfile as sf
data, samplerate = sf.read('stereo_file.wav')
print(data, samplerate)

# %%
# import required module
import glob
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf

# assign directory
directory = 'C:/Users/bhask/Desktop/Audio/test'
 
# iterate over files in
# that directory
for filename in glob.iglob(f'{directory}/*'):
    librosa.util.example_audio_file()
    librosa.get_samplerate(filename)

    data,samplerate = sf.read(filename)
    print(samplerate)
# Out:
# 44100

# %%
# # import required modules
# from os import path
# from pydub import AudioSegment
  
# # assign files
# input_file = "C:/Users/bhask/Desktop/Audio/modi/dataset/dataset1"
# output_file = "C:/Users/bhask/Desktop/Audio/modi/dataset/dataset1.wav"
  
# # convert mp3 file to wav file
# sound = AudioSegment.from_mp3(input_file)
# sound.export(output_file, format="wav")

# %%
filepath='C:/Users/bhask/Desktop/Audio/test/0_dataset1.wav'
samples, sampling_rate =librosa.load(filepath,sr= None)
print(sampling_rate)
# Out:
# 44100

# %%
# import required module
import glob
import librosa
# import librosa.display


# assign directory
directory = 'C:/Users/bhask/Desktop/Audio/modi/dataset/dataset/DATASET3'
 
# iterate over files in
# that directory
for filename in glob.iglob(f'{directory}/*'):
    samples, sampling_rate =librosa.load(filename,sr= None)
    print(sampling_rate)
# Out:
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# ...
